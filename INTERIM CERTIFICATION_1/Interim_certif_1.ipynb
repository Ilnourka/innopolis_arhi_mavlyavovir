# %%
#импортируем нужные модули и считываем исходный датафрейм
import pandas as pd
import matplotlib.pyplot as plt

df_init = pd.read_csv("dataset_tk.csv")
df_init
# Out:
#               Unnamed: 0  Punjab  Haryana  Rajasthan  Delhi     UP  \
# 0    02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9
# 1    03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8
# 2    04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7
# 3    05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0
# 4    06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8
# ..                   ...     ...      ...        ...    ...    ...
# 498  01/12/2020 00:00:00   130.8    126.0      220.4   77.3  322.8
# 499  02/12/2020 00:00:00   129.4    127.3      218.4   81.3  331.4
# 500  03/12/2020 00:00:00   132.1    129.7      205.6   85.6  336.7
# 501  04/12/2020 00:00:00   132.1    128.4      207.0   83.9  334.6
# 502  05/12/2020 00:00:00   120.4    111.2      201.4   83.6  287.3
#
#      Uttarakhand    HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0           40.7  30.0  52.5         5.0  ...    70.2        108.2     2.0
# ...

# %%
#выводим статистику по структуре данных
df = df_init.copy()
print(f"Датафрейм имеет {len(df.columns)} столбцов и {len(df)} строку")
print()
bsize = df.memory_usage(index=True).sum()
print(f"Датафрейм занимает {bsize} байт после прочтения")
print()
print(f"Столбцы имеют следующие типы данных")
print( df.dtypes.groupby(df.dtypes).count() )
# Out:
# Датафрейм имеет 34 столбцов и 503 строку
#
# Датафрейм занимает 136944 байт после прочтения
#
# Столбцы имеют следующие типы данных
# float64    33
# object      1
# dtype: int64

# %%
#cформируем кортеж из названий столбцов в нужном формате
df.columns = [ str(s).replace(" ", "_").lower() for s in df.columns ]
df
# Out:
#               unnamed:_0  punjab  haryana  rajasthan  delhi     up  \
# 0    02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9
# 1    03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8
# 2    04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7
# 3    05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0
# 4    06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8
# ..                   ...     ...      ...        ...    ...    ...
# 498  01/12/2020 00:00:00   130.8    126.0      220.4   77.3  322.8
# 499  02/12/2020 00:00:00   129.4    127.3      218.4   81.3  331.4
# 500  03/12/2020 00:00:00   132.1    129.7      205.6   85.6  336.7
# 501  04/12/2020 00:00:00   132.1    128.4      207.0   83.9  334.6
# 502  05/12/2020 00:00:00   120.4    111.2      201.4   83.6  287.3
#
#      uttarakhand    hp   j&k  chandigarh  ...  odisha  west_bengal  sikkim  \
# 0           40.7  30.0  52.5         5.0  ...    70.2        108.2     2.0
# ...

# %%
# определяем количество пустых ячеек в каждом столбце
print(df.isna().sum())

# заполняем пустые ячейки средними значениями по столбцу
df = df.fillna(df.mean())
# Out:
# unnamed:_0           0
# punjab               0
# haryana              0
# rajasthan            0
# delhi                0
# up                   0
# uttarakhand          0
# hp                   0
# j&k                  0
# chandigarh           0
# chhattisgarh         0
# gujarat              0
# mp                   0
# maharashtra          0
# goa                  0
# dnh                  0
# andhra_pradesh       0
# telangana            0
# karnataka            0
# kerala               0
# tamil_nadu           0
# pondy                0
# bihar                0
# jharkhand            0
# odisha               0
# west_bengal          0
# sikkim               0
# arunachal_pradesh    0
# assam                0
# manipur              0
# meghalaya            0
# mizoram              0
# nagaland             0
# tripura              0
# dtype: int64

# %%
# проверяем, что все ячейки заполнены
print()
print(df.isna().sum())
# Out:
# unnamed:_0           0
# punjab               0
# haryana              0
# rajasthan            0
# delhi                0
# up                   0
# uttarakhand          0
# hp                   0
# j&k                  0
# chandigarh           0
# chhattisgarh         0
# gujarat              0
# mp                   0
# maharashtra          0
# goa                  0
# dnh                  0
# andhra_pradesh       0
# telangana            0
# karnataka            0
# kerala               0
# tamil_nadu           0
# pondy                0
# bihar                0
# jharkhand            0
# odisha               0
# west_bengal          0
# sikkim               0
# arunachal_pradesh    0
# assam                0
# manipur              0
# meghalaya            0
# mizoram              0
# nagaland             0
# tripura              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'punjab', 'haryana', 'rajasthan', 'delhi', 'up',
#        'uttarakhand', 'hp', 'j&k', 'chandigarh', 'chhattisgarh', 'gujarat',
#        'mp', 'maharashtra', 'goa', 'dnh', 'andhra_pradesh', 'telangana',
#        'karnataka', 'kerala', 'tamil_nadu', 'pondy', 'bihar', 'jharkhand',
#        'odisha', 'west_bengal', 'sikkim', 'arunachal_pradesh', 'assam',
#        'manipur', 'meghalaya', 'mizoram', 'nagaland', 'tripura'],
#       dtype='object')

# %%
# проверяем, что все ячейки заполнены
print()
print(df.isna().sum())
# Out:
# unnamed:_0           0
# punjab               0
# haryana              0
# rajasthan            0
# delhi                0
# up                   0
# uttarakhand          0
# hp                   0
# j&k                  0
# chandigarh           0
# chhattisgarh         0
# gujarat              0
# mp                   0
# maharashtra          0
# goa                  0
# dnh                  0
# andhra_pradesh       0
# telangana            0
# karnataka            0
# kerala               0
# tamil_nadu           0
# pondy                0
# bihar                0
# jharkhand            0
# odisha               0
# west_bengal          0
# sikkim               0
# arunachal_pradesh    0
# assam                0
# manipur              0
# meghalaya            0
# mizoram              0
# nagaland             0
# tripura              0
# dtype: int64

# %%
df["Date"]=df["unnamed:_0"]
df['Date'] = pd.to_datetime(df.Date, dayfirst=True)
df = df.drop(["unnamed:_0"], axis = 1)

# %%
df
# Out:
#      punjab  haryana  rajasthan  delhi     up  uttarakhand    hp   j&k  \
# 0     119.9    130.3      234.1   85.8  313.9         40.7  30.0  52.5
# 1     121.9    133.5      240.2   85.5  311.8         39.3  30.1  54.1
# 2     118.8    128.2      239.8   83.5  320.7         38.1  30.1  53.2
# 3     121.0    127.5      239.1   79.2  299.0         39.2  30.2  51.5
# 4     121.4    132.6      240.4   76.6  286.8         39.2  31.0  53.2
# ..      ...      ...        ...    ...    ...          ...   ...   ...
# 498   130.8    126.0      220.4   77.3  322.8         36.5  25.4  45.4
# 499   129.4    127.3      218.4   81.3  331.4         37.0  25.8  45.2
# 500   132.1    129.7      205.6   85.6  336.7         37.8  26.2  45.2
# 501   132.1    128.4      207.0   83.9  334.6         38.2  27.0  43.0
# 502   120.4    111.2      201.4   83.6  287.3         35.2  24.3  42.6
#
#      chandigarh  chhattisgarh  ...  west_bengal  sikkim  arunachal_pradesh  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   punjab             503 non-null    float64
#  1   haryana            503 non-null    float64
#  2   rajasthan          503 non-null    float64
#  3   delhi              503 non-null    float64
#  4   up                 503 non-null    float64
#  5   uttarakhand        503 non-null    float64
#  6   hp                 503 non-null    float64
#  7   j&k                503 non-null    float64
#  8   chandigarh         503 non-null    float64
#  9   chhattisgarh       503 non-null    float64
#  10  gujarat            503 non-null    float64
#  11  mp                 503 non-null    float64
#  12  maharashtra        503 non-null    float64
#  13  goa                503 non-null    float64
#  14  dnh                503 non-null    float64
# ...

# %%
df['NR'] = df['punjab']+ df['haryana']+ df['rajasthan']+ df['delhi']+df['up']+df['uttarakhand']+df['hp']+df['j&k']+df['chandigarh']
df['WR'] = df['chhattisgarh']+df['gujarat']+df['mp']+df['maharashtra']+df['goa']+df['dnh']
df['SR'] = df['andhra_pradesh']+df['telangana']+df['karnataka']+df['kerala']+df['tamil_nadu']+df['pondy']
df['ER'] = df['bihar']+df['jharkhand']+ df['odisha']+df['west_bengal']+df['sikkim']
df['NER'] =df['arunachal_pradesh']+df['assam']+df['manipur']+df['meghalaya']+df['mizoram']+df['nagaland']+df['tripura']

# %%
df_line = pd.DataFrame({"Northern Region": df["NR"].values,
                        "Southern Region": df["SR"].values,
                        "Eastern Region": df["ER"].values,
                        "Western Region": df["WR"].values,
                        "North Eastern Region": df["NER"].values},index=df.Date)

# %%
plt.plot(df_line.index, df_line['Northern Region'],
        df_line.index, df_line['Southern Region'],
        df_line.index, df_line["Eastern Region"],
        df_line.index, df_line["Western Region"],
        df_line.index, df_line["North Eastern Region"])

plt.figure(figsize=(10000,6000))
#plt.rcParams['figure.figsize'] = [10, 10]
plt.show()

# %%
plot = df.hist()
plt.show()

# %%
df['ALL'] =df["NR"]+df["SR"]+df["ER"]+df["WR"]+df["NER"]
print()

# %%
df
# Out:
#      punjab  haryana  rajasthan  delhi     up  uttarakhand    hp   j&k  \
# 0     119.9    130.3      234.1   85.8  313.9         40.7  30.0  52.5
# 1     121.9    133.5      240.2   85.5  311.8         39.3  30.1  54.1
# 2     118.8    128.2      239.8   83.5  320.7         38.1  30.1  53.2
# 3     121.0    127.5      239.1   79.2  299.0         39.2  30.2  51.5
# 4     121.4    132.6      240.4   76.6  286.8         39.2  31.0  53.2
# ..      ...      ...        ...    ...    ...          ...   ...   ...
# 498   130.8    126.0      220.4   77.3  322.8         36.5  25.4  45.4
# 499   129.4    127.3      218.4   81.3  331.4         37.0  25.8  45.2
# 500   132.1    129.7      205.6   85.6  336.7         37.8  26.2  45.2
# 501   132.1    128.4      207.0   83.9  334.6         38.2  27.0  43.0
# 502   120.4    111.2      201.4   83.6  287.3         35.2  24.3  42.6
#
#      chandigarh  chhattisgarh  ...  mizoram  nagaland  tripura       Date  \
# ...

# %%
df_line = pd.DataFrame({'ALL':df['ALL'].values},index=df.Date)
plt.plot(df_line.index, df_line['ALL'])

plt.figure(figsize=(9000,20000))
#plt.rcParams['figure.figsize'] = [10, 10]

plt.show()

# %%
df2 = df.copy()
df2['day_name'] = df.Date.dt.weekday
df2
df2_SUM = df2[['day_name','ALL']].groupby('day_name').sum()
print(df2_SUM)
df2_SUM.plot(kind='bar', stacked=False)
plt.title('----')
plt.xlabel('day')
plt.ylabel('Count')
plt.ylim(230000, 260000)
plt.show()
# Out:
#                ALL
# day_name
# 0         238050.4
# 1         248506.8
# 2         247688.4
# 3         251435.1
# 4         244733.7
# 5         237554.4
# 6         241759.1

# %%
df2 = df.copy()
df2['day_name'] = df.Date.dt.day
df2
df2_SUM = df2[['day_name','ALL']].groupby('day_name').sum()
print(df2_SUM)
df2_SUM.plot(kind='bar', stacked=False)
plt.title('----')
plt.xlabel('day')
plt.ylabel('Count')
plt.show()
# Out:
#               ALL
# day_name
# 1         62630.1
# 2         81678.4
# 3         81592.6
# 4         81350.4
# 5         81672.2
# 6         40160.5
# 7         22434.8
# 8         40722.4
# 9         40675.4
# 10        41757.7
# 11        42334.8
# 12        44003.2
# 13        57716.6
# 14        58039.0
# 15        57502.4
# 16        58247.4
# 17        59688.7
# 18        59311.6
# 19        59691.8
# 20        58880.9
# 21        59337.1
# 22        58009.1
# 23        59011.6
# 24        55272.0
# 25        55075.5
# 26        54650.2
# 27        54794.1
# 28        53726.7
# 29        52004.7
# 30        47628.1
# 31        30127.9

# %%
df2 = df.copy()
df2['day_name'] = df.Date.dt.month
df2
df2_SUM = df2[['day_name','ALL']].groupby('day_name').sum()
print(df2_SUM)
df2_SUM.plot(kind='bar', stacked=False)
plt.title('----')
plt.xlabel('day')
plt.ylabel('Count')
plt.show()
# Out:
#                ALL
# day_name
# 1         186624.8
# 2         163661.8
# 3         176845.7
# 4         181393.1
# 5         155287.3
# 6         112436.8
# 7         135731.0
# 8         123408.3
# 9         119525.1
# 10        120979.2
# 11        111370.9
# 12        122463.9

# %%
import seaborn as sns

# %%
sns.pairplot(df2, x_vars=["NR"],  y_vars=['day_name'])

# %%
df2
# Out:
#      punjab  haryana  rajasthan  delhi     up  uttarakhand    hp   j&k  \
# 0     119.9    130.3      234.1   85.8  313.9         40.7  30.0  52.5
# 1     121.9    133.5      240.2   85.5  311.8         39.3  30.1  54.1
# 2     118.8    128.2      239.8   83.5  320.7         38.1  30.1  53.2
# 3     121.0    127.5      239.1   79.2  299.0         39.2  30.2  51.5
# 4     121.4    132.6      240.4   76.6  286.8         39.2  31.0  53.2
# ..      ...      ...        ...    ...    ...          ...   ...   ...
# 498   130.8    126.0      220.4   77.3  322.8         36.5  25.4  45.4
# 499   129.4    127.3      218.4   81.3  331.4         37.0  25.8  45.2
# 500   132.1    129.7      205.6   85.6  336.7         37.8  26.2  45.2
# 501   132.1    128.4      207.0   83.9  334.6         38.2  27.0  43.0
# 502   120.4    111.2      201.4   83.6  287.3         35.2  24.3  42.6
#
#      chandigarh  chhattisgarh  ...  nagaland  tripura       Date      NR  \
# ...

# %%
df3 = df2[['NR','WR','SR','ER','NER','ALL','day_name']]

# %%
sns.pairplot(df3)
